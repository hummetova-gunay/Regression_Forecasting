# %% [markdown]
# # Interaction Terms
# These terms capture feature-target relationships that change based on the value of another feature
# - We can detect them with careful EDA or brute - force engineering (or more advanced black box algorithms such as gradient boosting, random forest will pick up interaction terms naturally)
#
# Adding interaction terms:
# $y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \beta_3 x_1x_2$

# %%
# insurance_df = insurance_df.assing(
#     smoker_flag = np.where(insurance_df['smoker'] == 'yes', 1,0),
#     age_sq = insurance_df['age']**2,
#     smoker_bmi_int = lambda x: x['smoker_flag']*x['bmi']
# )
