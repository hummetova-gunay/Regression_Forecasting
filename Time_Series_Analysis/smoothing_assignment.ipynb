# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Course Materials/Data/powerconsumption.csv')

# %%
df.head()
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
# 3  1/1/2017 0:30        6.121      75.0      0.083                0.091
# 4  1/1/2017 0:40        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3
# 0             20240.96386
# 1             20131.08434
# 2             19668.43373
# 3             18899.27711
# ...

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
df.head()
# Out:
#              Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0 2017-01-01 00:00:00        6.559      73.8      0.083                0.051
# 1 2017-01-01 00:10:00        6.414      74.5      0.083                0.070
# 2 2017-01-01 00:20:00        6.313      74.5      0.080                0.062
# 3 2017-01-01 00:30:00        6.121      75.0      0.083                0.091
# 4 2017-01-01 00:40:00        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3
# 0             20240.96386
# 1             20131.08434
# 2             19668.43373
# ...

# %%
df = df.set_index('Datetime').resample('H').mean()
# Out:
# C:\Users\ghummatova\AppData\Local\Temp\ipykernel_14276\3903601270.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df = df.set_index('Datetime').resample('H').mean()

# %%
df.head()
# Out:
#                      Temperature   Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00     6.196833  75.066667   0.081833             0.063500
# 2017-01-01 01:00:00     5.548833  77.583333   0.082000             0.056833
# 2017-01-01 02:00:00     5.054333  78.933333   0.082333             0.063000
# 2017-01-01 03:00:00     5.004333  77.083333   0.082833             0.059833
# 2017-01-01 04:00:00     5.097667  74.050000   0.082333             0.058000
#
#                      DiffuseFlows  PowerConsumption_Zone1  \
# Datetime
# 2017-01-01 00:00:00      0.098833            29197.974683
# 2017-01-01 01:00:00      0.112500            24657.215190
# 2017-01-01 02:00:00      0.129167            22083.037973
# 2017-01-01 03:00:00      0.141000            20811.139240
# 2017-01-01 04:00:00      0.122833            20475.949367
#
#                      PowerConsumption_Zone2  PowerConsumption_Zone3
# Datetime
# ...

# %% [markdown]
# ### Assignment 1: Rolling Average
# 1. Plot a line chart of the raw PowerConsumption_Zone1 series
# 2. Calculate a 1 week (7*24) period moving average and plot
# 3. Finally, calculate a 30-day (30*24) period moving avergae and plot

# %%
df['PowerConsumption_Zone1'].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
df['PowerConsumption_Zone1'].rolling(24*7).mean().plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
df['PowerConsumption_Zone1'].rolling(24*30).mean().plot()
# Out:
# <Axes: xlabel='Datetime'>
